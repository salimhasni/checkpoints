# %%
import pandas as pd
df=pd.read_csv("C:/Users/HP/Desktop/GoMyCode/titanic-passengers.csv",sep=";")

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708   NaN        C
# 887      0    2669   7.2292   NaN        C
# 888      0  315084   8.6625   NaN        S
# 889      0  349215   7.8958   NaN        S
# 890      0  250655  26.0000   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 866

# %%
df["Age"].fillna(df["Age"].median(),inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
number_of_elements = len(df["Cabin"])
print("number of elements :" ,number_of_elements)
print(df["Cabin"].value_counts())
# Out:
# number of elements : 891
# C23 C25 C27    4
# G6             4
# B96 B98        4
# D              3
# F33            3
#               ..
# C70            1
# A10            1
# A31            1
# D21            1
# C110           1
# Name: Cabin, Length: 147, dtype: int64

# %%
df["Cabin"].fillna('G6',inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
number_of_elements1 = len(df["Embarked"])
print("number of elements :" ,number_of_elements)
print(df["Embarked"].value_counts())
# Out:
# number of elements : 891
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df["Embarked"].fillna('S',inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.title("histogram of diffrent ages")
plt.xlabel("ages")
df["Age"].plot.hist()

# %%
sns.boxplot(data=df)

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#df["Age"]=scaler.fit_transform(df[["Age"]].values)
#df["Fare"]=scaler.fit_transform(df[["Fare"]].values)
#df["Pclass"]=scaler.fit_transform(df[["Pclass"]].values)
#sns.boxplot(data=df)

# %%
g=sns.FacetGrid(df,col='Sex')
g.map(plt.hist,'Age')

# %%
g1=sns.FacetGrid(df,col='Survived')
g1.map(plt.hist,'Age')

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map(df)

# %% [markdown]
# The plot_correlation_map function creates a correlation matrix that measures the correlation between each pair of features on a scale from -0.4 to 1.0 (1.0 for a perfect correlation),that's why the diagonal values are all 1.0 because it's a correlation between the same feature,and the matrix is diagonal

# %%
cleanup={"Survived":{"Yes":1, "No": 0}}
df1=df.replace(cleanup,inplace=False)
df1[["Pclass","Survived"]].groupby(["Pclass"], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df.drop("Name", inplace=True, axis=1)

# %%
df
# Out:
#      PassengerId Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# 0            343       No       2    male  28.0      0      0      248740
# 1             76       No       3    male  25.0      0      0      348123
# 2            641       No       3    male  20.0      0      0      350050
# 3            568       No       3  female  29.0      0      4      349909
# 4            672       No       1    male  31.0      1      0  F.C. 12750
# ..           ...      ...     ...     ...   ...    ...    ...         ...
# 886           10      Yes       2  female  14.0      1      0      237736
# 887           61       No       3    male  22.0      0      0        2669
# 888          535       No       3  female  30.0      0      0      315084
# 889          102       No       3    male  28.0      0      0      349215
# 890          428      Yes       2  female  19.0      0      0      250655
#
#         Fare  Cabin Embarked
# 0    13.0000     G6        S
# ...

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#make a new column from an existing one 
import re 
#import pyparsing as pp
#testing extraction
 #names=df1["Name"]
 #a=names[1]
 #a1=re.split(', |. |\*|\n',a)[1]
 #a1
#probleme
 #df1.assign(Title=lambda x: (x.Name)[(x.Name).find(start:=',')+len(start):(x.Name).find('.')])
#2eme methode
 #word=df1["Name"][1]
 #word1= pp.Word(pp.alphanums)
 #rule =pp.nestedExpr(',','.')
 #for match in rule.searchString(word):
     #print(match)
#word[word.find(start:=',')+len(start):word.find('.')]

#extracting titles from names


titles = df1["Name"].str.split(",")
#var=value.split(',')[1].split('.')[0]
#var=re.split(', |. |\*|\n',value)[1]
#creating a new column to fill with titles 
#df1['Titles']=titles
#df1
titles_extracted=[]
for element in titles:
    titles_extracted.append(element[1].split(".")[0])
titles_extracted2=[]
for title in titles_extracted:
    print(title)
    titles_extracted2.append(title.strip())

df1['Titles']=titles_extracted2
# Out:
#  Mr
#  Mr
#  Mr
#  Mrs
#  Mr
#  Mr
#  Mr
#  Miss
#  Mr
#  Mrs
#  Mr
#  Miss
#  Mrs
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Miss
#  Mr
#  Mr
#  Mr
#  Mrs
#  Mr
#  Mr
#  Dr
#  Mr
#  Miss
#  Mr
#  Mr
#  Mr
#  Major
#  Mrs
#  Don
#  Mr
#  Mr
#  Mr
#  Miss
#  Miss
#  Mr
#  Mr
#  Miss
#  Mr
#  Miss
#  Mr
#  Master
#  Dr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mrs
#  Mrs
#  Miss
#  Miss
#  Master
#  Miss
#  Mr
#  Rev
#  Mr
#  Mrs
#  Mrs
#  Miss
#  Mr
#  Mrs
#  Mr
#  Mr
#  Miss
#  Mr
#  Miss
#  Miss
#  Miss
#  Mrs
#  Master
#  Mr
#  Mr
#  Mr
#  Mr
#  Miss
#  Mr
#  Mr
#  Mrs
#  Mrs
#  Miss
#  Mrs
#  Mr
#  Mr
#  Mr
#  Miss
#  Mrs
#  Mr
#  Mr
#  Mr
#  Master
#  Mr
#  Mr
#  Mr
#  Mr
#  Mrs
#  Miss
#  Mr
#  Mr
#  Master
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Miss
#  Mr
#  Mr
#  Col
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Mr
#  Miss
#  Mr
#  Mr
#  Miss
#  Mr
#  Mrs
#  Miss
#  Mr
#  Miss
#  Mrs
#  Miss
#  Mr
#  Mr
#  Mr
#  Mrs
#  Mr
#  Miss
#  Mrs
#  Mr
# ...

# %%
titles_extracted2
# Out:
# ['Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Dr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Major',
#  'Mrs',
#  'Don',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Master',
#  'Dr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Miss',
#  'Master',
#  'Miss',
#  'Mr',
#  'Rev',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Mr',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Miss',
#  'Miss',
#  'Miss',
#  'Mrs',
#  'Master',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mr',
#  'Mr',
#  'Mrs',
#  'Mrs',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
#  'Miss',
#  'Mrs',
#  'Mr',
#  'Mr',
#  'Mr',
# ...

# %%
grid=sns.FacetGrid(df1,row="Titles",col="Survived",height=2.2,aspect=1.6)
grid.map(sns.barplot,"SibSp",alpha=.5,ci=None)
grid.add_legend()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
set(df1["Titles"])
# Out:
# {'Capt',
#  'Col',
#  'Don',
#  'Dr',
#  'Jonkheer',
#  'Lady',
#  'Major',
#  'Master',
#  'Miss',
#  'Mlle',
#  'Mme',
#  'Mr',
#  'Mrs',
#  'Ms',
#  'Rev',
#  'Sir',
#  'the Countess'}

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess":"Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }

# %%
df1=df1.replace({"Titles":Title_Dictionary})

# %%
set(df1["Titles"])
# Out:
# {'Master', 'Miss', 'Mrs', 'Officer', 'Royalty'}

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
grid=sns.FacetGrid(df1,row="Titles",col="Survived",height=2.2,aspect=1.6)
grid.map(sns.barplot,"SibSp",alpha=.5,ci=None)
grid.add_legend()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#create a new feature from SibSp and Parch 
df1["FamilySize"]=df1.Parch + df1.SibSp

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.drop(["family","Name","Parch","SibSp"],axis=1,inplace=True)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass     Sex   Age      Ticket     Fare  Cabin  \
# 0            343         0       2    male  28.0      248740  13.0000     G6
# 1             76         0       3    male  25.0      348123   7.6500  F G73
# 2            641         0       3    male  20.0      350050   7.8542     G6
# 3            568         0       3  female  29.0      349909  21.0750     G6
# 4            672         0       1    male  31.0  F.C. 12750  52.0000    B71
# ..           ...       ...     ...     ...   ...         ...      ...    ...
# 886           10         1       2  female  14.0      237736  30.0708     G6
# 887           61         0       3    male  22.0        2669   7.2292     G6
# 888          535         0       3  female  30.0      315084   8.6625     G6
# 889          102         0       3    male  28.0      349215   7.8958     G6
# 890          428         1       2  female  19.0      250655  26.0000     G6
#
#     Embarked Titles  FamilySize
# ...

# %%
plot_correlation_map(df1)

# %% [markdown]
# As we can see,the FamilySize feature is lowly correlated with the output variable .
# For that we can coclude that this feature is not useful
